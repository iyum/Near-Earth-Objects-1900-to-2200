# %% [markdown]
# IMPORT LIBRARIES

# %%
# IMPORT LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/NEO Earth Close Approaches.csv')

# %% [markdown]
# DATA EXPLORATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35899 entries, 0 to 35898
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Object                    35899 non-null  object
#  1   Close-Approach (CA) Date  35899 non-null  object
#  2   CA DistanceNominal (au)   35899 non-null  float64
#  3   CA DistanceMinimum (au)   35899 non-null  float64
#  4   V relative(km/s)          35899 non-null  float64
#  5   V infinity(km/s)          35877 non-null  float64
#  6   H(mag)                    35890 non-null  float64
#  7   Diameter                  35891 non-null  object
#  8   Rarity                    35890 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 2.5+ MB

# %%
df.rename(columns=
          {'CA DistanceNominal (au)':"Dist_Nom",
           "CA DistanceMinimum (au)":"Dist_min", 
           "V relative(km/s)":"V_real",
           "V infinity(km/s)":"V_inf"},
          inplace=True)

# %%
df.head()
# Out:
#                   Object      Close-Approach (CA) Date  Dist_Nom  Dist_min  \
# 0       509352 (2007 AG)  1900-Jan-04 22:25 ±    00:02   0.00963   0.00962
# 1           (2014 SC324)  1900-Jan-11 01:07 ±    00:18   0.03997   0.03991
# 2           (2012 UK171)  1900-Jan-12 23:07 ±    00:13   0.04982   0.04950
# 3  4660 Nereus (1982 DB)  1900-Jan-29 18:10 ±    00:35   0.02080   0.02077
# 4            (2015 RW83)  1900-Feb-04 03:50 ±    14:49   0.03312   0.03258
#
#    V_real  V_inf  H(mag)        Diameter  Rarity
# 0    8.69   8.65    20.2  250 m -  550 m     2.0
# 1   10.65  10.65    24.3   37 m -   82 m     0.0
# 2    7.16   7.15    24.4   34 m -   77 m     0.0
# 3    5.54   5.52    18.6    0.33±0.05 km     2.0
# 4    3.14   3.12    24.1   40 m -   90 m     0.0

# %%
df.describe()
# Out:
#            Dist_Nom      Dist_min        V_real         V_inf        H(mag)  \
# count  35899.000000  35899.000000  35899.000000  35877.000000  35890.000000
# mean       0.027882      0.024017     10.407677     10.384499     24.860669
# std        0.013840      0.014188      5.393484      5.400947      2.653903
# min        0.000050      0.000000      0.140000      0.220000     13.900000
# 25%        0.016700      0.011810      6.590000      6.560000     23.400000
# 50%        0.029000      0.023850      9.360000      9.340000     25.300000
# 75%        0.039790      0.036050     13.160000     13.140000     26.700000
# max        0.050000      0.050000     42.920000     42.910000     33.200000
#
#              Rarity
# count  35890.000000
# mean       0.361354
# std        0.657575
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        6.000000

# %%
impact = df.query('Dist_min == 0')
impact
# Out:
#             Object      Close-Approach (CA) Date  Dist_Nom  Dist_min  V_real  \
# 3402   (2012 HA34)   1945-May-04 02:11 ± 4_02:10   0.01251       0.0   11.41
# 10566  (2008 EK68)   2008-Mar-03 10:14 ± 2_02:10   0.00388       0.0    8.74
# 10650  (2008 JD33)   2008-May-10 18:03 ± 6_06:49   0.02998       0.0    5.90
# 10968   (2009 JE1)   2009-May-09 07:37 ± 1_16:14   0.01556       0.0    7.91
# 11406  (2010 SV15)   2010-Sep-21 21:55 ± 1_21:47   0.03541       0.0    8.90
# 11529    (2010 XC)   2010-Dec-05 20:39 ± 1_01:51   0.01148       0.0    5.38
# 11555   (2011 AE3)  2011-Jan-03 13:17 ±    13:13   0.00569       0.0    6.63
# 11593  (2011 CH22)   2011-Feb-04 23:08 ± 2_04:14   0.00846       0.0    5.39
# 14326  (2016 QY84)   2016-Aug-23 20:23 ± 7_14:16   0.00835       0.0    3.90
# 15306  (2017 UL52)   2017-Oct-20 07:38 ± 1_01:13   0.01031       0.0    6.12
# 24663    (2021 XV)   2045-Nov-30 11:59 ± 6_23:27   0.00656       0.0   10.93
#
#        V_inf  H(mag)        Diameter  Rarity
# ...

# %%
# numerical value on histogram
df_num =  df[['Dist_Nom','Dist_min','V_real','V_inf','H(mag)']]
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
print(df_num.corr())
plt.figure(figsize=(10,5))
sns.heatmap(df_num.corr())
# Out:
#           Dist_Nom  Dist_min    V_real     V_inf    H(mag)
# Dist_Nom  1.000000  0.836637  0.002130  0.006774 -0.320605
# Dist_min  0.836637  1.000000  0.021974  0.025878 -0.430534
# V_real    0.002130  0.021974  1.000000  0.999782 -0.425466
# V_inf     0.006774  0.025878  0.999782  1.000000 -0.427908
# H(mag)   -0.320605 -0.430534 -0.425466 -0.427908  1.000000
# <AxesSubplot:>

# %%
df_cat = df[['Rarity']]

for i in df_cat.columns:
    sns.barplot(x=df_cat[i].value_counts().index,
                y=df_cat[i].value_counts()).set_title(i)
    plt.show()

# %%
df_cat.query('Rarity>3')
# Out:
#        Rarity
# 1036      4.0
# 1277      4.0
# 1757      4.0
# 2271      4.0
# 2366      4.0
# 2745      4.0
# 3152      4.0
# 4573      5.0
# 5858      4.0
# 6016      4.0
# 6401      4.0
# 7077      4.0
# 7845      4.0
# 8166      4.0
# 8573      4.0
# 9114      4.0
# 9241      4.0
# 9656      4.0
# 10090     4.0
# 12375     4.0
# 14057     4.0
# 15094     4.0
# 15127     4.0
# 17072     4.0
# 23015     4.0
# 23024     4.0
# 23095     5.0
# 23128     4.0
# 23189     6.0
# 24048     4.0
# 24274     4.0
# 25827     4.0
# 25909     4.0
# 26661     4.0
# 27126     4.0
# 27396     4.0
# 27482     4.0
# 27727     4.0
# 27802     4.0
# 28071     4.0
# 28210     4.0
# 29075     4.0
# 29455     4.0
# 30042     4.0
# 30099     4.0
# 31288     4.0
# 32147     4.0
# 32554     4.0
# 32857     4.0
# 33305     4.0
# 33322     4.0
# 35406     4.0
# 35764     4.0
# 35787     4.0
